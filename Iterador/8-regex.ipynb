# %%
import re

# %%
def explorar_expressao_regular(texto):
    padrao = r'\bPython\b'
    if re.search(padrao, texto):
        print("O padrão foi encontrado no texto")
    else:
        print("O padrão não foi encontrado no texto.")
    #Identificar emails
    padrao_email = r'[a-zA-Z0-9._%+-]+@[a-zA-Z0-9._]+\.[a-zA-Z]{2,}'
    emails = re.findall(padrao_email,texto)
    print(f"E-mails encontrados: {emails}")
    #Substituir um padrão por outro
    texto_substituido = re.sub(r'Python','JavaScript', texto)
    print(texto_substituido)
    #dividir uma sting com base em um padrão 
    texto_dividido =  re.split(r'\s+',texto)
    print(texto_dividido)

# %%
texto_exemplo = """
Olá , eu sou um desenvolvedor Python.
Você pode me contatar em meu email : exemplo@domineo.com.
Python pe uma linguagem de programação popular
"""
explorar_expressao_regular(texto_exemplo)
# Out:
# O padrão foi encontrado no texto
# E-mails encontrados: ['exemplo@domineo.com']
#
# Olá , eu sou um desenvolvedor JavaScript.
# Você pode me contatar em meu email : exemplo@domineo.com.
# JavaScript pe uma linguagem de programação popular
#
# ['', 'Olá', ',', 'eu', 'sou', 'um', 'desenvolvedor', 'Python.', 'Você', 'pode', 'me', 'contatar', 'em', 'meu', 'email', ':', 'exemplo@domineo.com.', 'Python', 'pe', 'uma', 'linguagem', 'de', 'programação', 'popular', '']
