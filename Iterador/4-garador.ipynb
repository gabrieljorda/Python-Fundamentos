# %% [markdown]
# Yield
# - É uma palavra chave para criar geradores . Quando você ussa em uma funçao , você trasforma a função em um gerador , que é um tipo especial de um iterador
# -Return : Quando é usado numa função, é encerrado e o valor é retornado . Chamadas subsequentes à função iniciam a execução do código.
# Yield : Pode seer chanada novamente e retomar a exevução do ponto onde foi pausada  , permitindo a produção de uma sequência de valores ao longo do tempo

# %%
def numeros_impares(n):
    for i in range(1, n+1,2):
        yield i

# %%
for numero in numeros_impares(10):
    print(numero)
# Out:
# 1
# 3
# 5
# 7
# 9
