# %%
import re

# %%
def valida_contatos(contatos):
    padrao_nome = r'Nome:\s*([A-Z][a-z]+(?:\s[A-Z][a-z]+)?)'
    padrao_email = r'Email: \s*([a-zA-Z0-9._%+-]+@[a-zA-Z0-9._]+\.[a-zA-Z]{2,})'
    padrao_telefone = r'Telefone:\s*(\(\d{2}\)\s\d{5}-\d{4}|\d{5}-\d{4})'
    for contato in contatos:
        nome_match = re.search(padrao_nome,contato)
        email_match = re.search(padrao_email,contato)
        telefone_match = re.search(padrao_telefone,contato)
        
        if nome_match and email_match and telefone_match:
            nome = nome_match.group(1)
            email = email_match.group(1)
            telefone = telefone_match.group(1)
            print(f"Contato válido: Nome:{nome},Email:{email},Telefone:{telefone}")
        else:
            print(f"Contato inválido: {contato}")

# %%
contatos_exemplo = [
    "Nome: Alice Silva, Email: alice.silva@example.com, Telefone: (11) 98765-4321",
    "Nome: Bruno Costa, Email: bruno.costa@example.com, Telefone: (21) 99874-5632",
    "Nome: Carla Mendes, Email: carla.mendes@example.com, Telefone: (31) 91234-7788",
    "Nome: Diego Rocha, Email: diego.rocha@example.com, Telefone: (41) 97654-2211",
    "Nome: Eduardo Lima, Email: eduardo.lima@example.com, Telefone: (51) 98888-9900",
    "Nome: Fernanda Alves, Email: fernanda.alves@examplecom, Telefone: () 93456-1122",
    "Nome: Gabriel Pires, Email: gabriel.pires@example.com, Telefone: (71) 96543-7789",
    "Nome: Helena Nogueira, Email: helena.nogueira@example.com, Telefone: (81) 97777-3344",
    "Nome: Igor Santos, Email: igor.santos@example.com, Telefone: (91) 95555-6677",
    "Nome: Juliana Freitas, Email: juliana.freitas@example.com, Telefone: (85) 96666-8899"
]

# %%
valida_contatos(contatos_exemplo)
# Out:
# Contato válido: Nome:Alice Silva,Email:alice.silva@example.com,Telefone:(11) 98765-4321
# Contato válido: Nome:Bruno Costa,Email:bruno.costa@example.com,Telefone:(21) 99874-5632
# Contato válido: Nome:Carla Mendes,Email:carla.mendes@example.com,Telefone:(31) 91234-7788
# Contato válido: Nome:Diego Rocha,Email:diego.rocha@example.com,Telefone:(41) 97654-2211
# Contato válido: Nome:Eduardo Lima,Email:eduardo.lima@example.com,Telefone:(51) 98888-9900
# Contato inválido: Nome: Fernanda Alves, Email: fernanda.alves@examplecom, Telefone: () 93456-1122
# Contato válido: Nome:Gabriel Pires,Email:gabriel.pires@example.com,Telefone:(71) 96543-7789
# Contato válido: Nome:Helena Nogueira,Email:helena.nogueira@example.com,Telefone:(81) 97777-3344
# Contato válido: Nome:Igor Santos,Email:igor.santos@example.com,Telefone:(91) 95555-6677
# Contato válido: Nome:Juliana Freitas,Email:juliana.freitas@example.com,Telefone:(85) 96666-8899
